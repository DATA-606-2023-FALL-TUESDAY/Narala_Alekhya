# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import zipfile

# %%
import os

# %%
def extract_zip_file(zip_path, destination):
    """
    Extracts the contents of the ZIP file to the specified destination.

    Parameters:
    - zip_path: Path to the ZIP file.
    - destination: Directory where the ZIP file should be extracted.
    """
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(destination)


def collect_image_data(root_path):


    data = []
    for dirpath, dirnames, filenames in os.walk(root_path):
        for file in filenames:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                label = os.path.basename(dirpath)
                image_path = os.path.join(dirpath, file)
                data.append([image_path, label])
    return data


def create_dataframe_from_data(data):

    return pd.DataFrame(data, columns=['Image_path', 'Label'])


# Example usage:
zip_path = '/content/drive/MyDrive/Capstone/Garbage.zip'
destination = 'Project'

extract_zip_file(zip_path, destination)
data = collect_image_data(destination)
df = create_dataframe_from_data(data)

df.head()
# Out:
#                                           Image_path    Label
# 0  Project/__MACOSX/Garbage/plastic/._plastic593.jpg  plastic
# 1  Project/__MACOSX/Garbage/plastic/._plastic731.jpg  plastic
# 2   Project/__MACOSX/Garbage/plastic/._plastic15.jpg  plastic
# 3  Project/__MACOSX/Garbage/plastic/._plastic396.jpg  plastic
# 4  Project/__MACOSX/Garbage/plastic/._plastic687.jpg  plastic

# %%
import plotly.express as px

# Prepare the data for Plotly Express
df_counts = df['Label'].value_counts().reset_index()
df_counts.columns = ['Garbage Type', 'Counts']

# Create a bar chart using Plotly Express
fig = px.bar(df_counts,
             x='Garbage Type',
             y='Counts',
             title='Value Counts for Each Type of Garbage',
             labels={'Garbage Type': 'Type of Garbage', 'Counts': 'Counts'},
             color='Garbage Type',
             category_orders={"Garbage Type": df_counts['Garbage Type'].tolist()},
             text='Counts',  # Add count labels on top of the bars
             color_discrete_sequence=px.colors.qualitative.Dark2)  # Set color scheme

# Customize the layout
fig.update_traces(marker=dict(line=dict(width=0.5, color='DarkSlateGrey')))
fig.update_xaxes(title_text=None)  # Remove x-axis label
fig.update_yaxes(title_text=None)  # Remove y-axis label

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="521c6b7f-7917-41be-a900-0622d860cfb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("521c6b7f-7917-41be-a900-0622d860cfb0")) {                    Plotly.newPlot(                        "521c6b7f-7917-41be-a900-0622d860cfb0",                        [{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"clothes","marker":{"color":"rgb(27,158,119)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"clothes","offsetgroup":"clothes","orientation":"v","showlegend":true,"text":[21300.0],"textposition":"auto","x":["clothes"],"xaxis":"x","y":[21300],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"shoes","marker":{"color":"rgb(217,95,2)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"shoes","offsetgroup":"shoes","orientation":"v","showlegend":true,"text":[7908.0],"textposition":"auto","x":["shoes"],"xaxis":"x","y":[7908],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"paper","marker":{"color":"rgb(117,112,179)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"paper","offsetgroup":"paper","orientation":"v","showlegend":true,"text":[4200.0],"textposition":"auto","x":["paper"],"xaxis":"x","y":[4200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"biological","marker":{"color":"rgb(231,41,138)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"biological","offsetgroup":"biological","orientation":"v","showlegend":true,"text":[3940.0],"textposition":"auto","x":["biological"],"xaxis":"x","y":[3940],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"battery","marker":{"color":"rgb(102,166,30)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"battery","offsetgroup":"battery","orientation":"v","showlegend":true,"text":[3780.0],"textposition":"auto","x":["battery"],"xaxis":"x","y":[3780],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cardboard","marker":{"color":"rgb(230,171,2)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"cardboard","offsetgroup":"cardboard","orientation":"v","showlegend":true,"text":[3564.0],"textposition":"auto","x":["cardboard"],"xaxis":"x","y":[3564],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"plastic","marker":{"color":"rgb(166,118,29)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"plastic","offsetgroup":"plastic","orientation":"v","showlegend":true,"text":[3460.0],"textposition":"auto","x":["plastic"],"xaxis":"x","y":[3460],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Garbage=%{x}\u003cbr\u003eCounts=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"white-glass","marker":{"color":"rgb(102,102,102)","pattern":{"shape":""},"line":{"color":"DarkSlateGrey","width":0.5}},"name":"white-glass","offsetgroup":"white-glass","orientation":"v","showlegend" ...
